# %% [markdown]
# **Final Presentation**

# %% [markdown]
# **Names & matriculation No :-**
#
#
# Kaushik Soni (3119685)

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e13fdb33-d958-416c-af28-3ee8d7037ca1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e13fdb33-d958-416c-af28-3ee8d7037ca1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ***Pandas***

# %%
my_df=pd.read_csv('videogames.csv')
my_df
# Out:
#                                                 Title  Features.Max Players  \
# 0                                   Super Mario 64 DS                     1
# 1                              Lumines: Puzzle Fusion                     1
# 2                                  WarioWare Touched!                     2
# 3                            Hot Shots Golf: Open Tee                     1
# 4                                        Spider-Man 2                     1
# ..                                                ...                   ...
# 144                                         Nanostray                     1
# 145                                       Sega Casino                     1
# 146  Teenage Mutant Ninja Turtles 3: Mutant Nightmare                     1
# 147                                   Pac-Man World 3                     1
# 148                                           Tokobot                     1
#
# ...

# %%
data2 = my_df.rename(columns={'Title':'Model','Features.Max Players':'Max Players'})
data2
# Out:
#                                                 Model  Max Players  \
# 0                                   Super Mario 64 DS            1
# 1                              Lumines: Puzzle Fusion            1
# 2                                  WarioWare Touched!            2
# 3                            Hot Shots Golf: Open Tee            1
# 4                                        Spider-Man 2            1
# ..                                                ...          ...
# 144                                         Nanostray            1
# 145                                       Sega Casino            1
# 146  Teenage Mutant Ninja Turtles 3: Mutant Nightmare            1
# 147                                   Pac-Man World 3            1
# 148                                           Tokobot            1
#
#                     Metadata.Genres Metadata.Publishers  Metrics.Review Score  \
# 0                            Action            Nintendo                    85
# ...

# %%
data3= data2.replace({2004:1,2005:2,})
data3
# Out:
#                                                 Model  Max Players  \
# 0                                   Super Mario 64 DS            1
# 1                              Lumines: Puzzle Fusion            1
# 2                                  WarioWare Touched!            2
# 3                            Hot Shots Golf: Open Tee            1
# 4                                        Spider-Man 2            1
# ..                                                ...          ...
# 144                                         Nanostray            1
# 145                                       Sega Casino            1
# 146  Teenage Mutant Ninja Turtles 3: Mutant Nightmare            1
# 147                                   Pac-Man World 3            1
# 148                                           Tokobot            1
#
#                     Metadata.Genres Metadata.Publishers  Metrics.Review Score  \
# 0                            Action            Nintendo                    85
# ...

# %%
array_y = np.array(data3['Metrics.Review Score'])
array_y
# Out:
# array([85, 89, 81, 81, 61, 67, 88, 75, 68, 46, 62, 75, 63, 74, 51, 73, 60,
#        74, 72, 48, 66, 76, 91, 83, 77, 77, 88, 86, 74, 89, 74, 72, 62, 82,
#        69, 82, 83, 44, 70, 86, 75, 74, 79, 79, 63, 75, 86, 74, 83, 63, 68,
#        83, 65, 88, 80, 81, 85, 81, 67, 73, 86, 77, 73, 71, 81, 80, 89, 67,
#        58, 79, 90, 81, 59, 64, 75, 73, 72, 66, 84, 75, 74, 45, 79, 79, 72,
#        75, 81, 73, 68, 84, 67, 78, 37, 79, 80, 61, 70, 66, 65, 56, 84, 65,
#        38, 88, 50, 63, 74, 75, 72, 66, 83, 54, 72, 68, 59, 66, 51, 66, 73,
#        80, 35, 75, 58, 65, 66, 64, 43, 61, 74, 49, 75, 75, 64, 70, 34, 60,
#        73, 68, 69, 69, 61, 65, 69, 68, 71, 61, 58, 61, 72])

# %%
data4= data3.drop(columns=['Model','Metadata.Genres','Metrics.Review Score','Metadata.Publishers','Release.Console'])
data4
# Out:
#      Max Players  Metrics.Sales  Metrics.Used Price  Release.Year
# 0              1           4.69               24.95             1
# 1              1           0.56               14.95             1
# 2              2           0.54               22.95             1
# 3              1           0.49               12.95             1
# 4              1           0.45               14.95             1
# ..           ...            ...                 ...           ...
# 144            1           0.06               17.95             2
# 145            1           0.06               17.95             2
# 146            1           0.06               17.95             2
# 147            1           0.06               24.95             2
# 148            1           0.06               17.95             2
#
# [149 rows x 4 columns]

# %%
array_x = np.array(data4)
array_x
# Out:
# array([[ 1.  ,  4.69, 24.95,  1.  ],
#        [ 1.  ,  0.56, 14.95,  1.  ],
#        [ 2.  ,  0.54, 22.95,  1.  ],
#        [ 1.  ,  0.49, 12.95,  1.  ],
#        [ 1.  ,  0.45, 14.95,  1.  ],
#        [ 1.  ,  0.41, 12.95,  1.  ],
#        [ 1.  ,  0.36, 19.95,  1.  ],
#        [ 1.  ,  0.34, 17.95,  1.  ],
#        [ 1.  ,  0.25,  8.95,  1.  ],
#        [ 1.  ,  0.22, 24.95,  1.  ],
#        [ 1.  ,  0.2 , 14.95,  1.  ],
#        [ 1.  ,  0.16,  8.95,  1.  ],
#        [ 1.  ,  0.15,  9.95,  1.  ],
#        [ 1.  ,  0.14, 14.95,  1.  ],
#        [ 4.  ,  0.13, 14.95,  1.  ],
#        [ 1.  ,  0.12,  8.95,  1.  ],
#        [ 1.  ,  0.11, 14.95,  1.  ],
#        [ 1.  ,  0.1 , 14.95,  1.  ],
#        [ 1.  ,  0.09, 14.95,  1.  ],
#        [ 1.  ,  0.06,  8.95,  1.  ],
#        [ 1.  ,  0.05, 16.95,  1.  ],
#        [ 1.  ,  0.04, 19.95,  1.  ],
#        [ 1.  ,  9.99, 29.95,  2.  ],
#        [ 1.  ,  9.72, 26.95,  2.  ],
#        [ 1.  ,  5.07, 17.95,  2.  ],
# ...

# %% [markdown]
# Visualizations

# %% [markdown]
# Line Graph

# %%
import matplotlib.pyplot as plt

x = ["Super Mario 64 DS", "Lumines: Puzzle Fusion", "WarioWare Touched!", "Hot Shots Golf: Open Tee", "Spider-Man 2"]
y = [4.69, 0.56, 0.54, 0.49, 0.45]

# %%
plt.xlabel('Video Games')
plt.ylabel('Metrics.Sales,')
plt.title('Sales of Video Games')

plt.plot(x, y)
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Scatter

# %%
x=data2['Model'].head(15)
y=data2['Metrics.Review Score'].head(15)


fig, ax = plt.subplots(figsize=(12,10))


ax.scatter(x, y, marker='o', color='b')


ax.set_xlabel('Video Games')
ax.set_ylabel('Metrics.Review Score')
ax.set_title('Score')

plt.xticks(rotation='vertical')


plt.show()

# %% [markdown]
# Bar Graph

# %%
import pandas as pd
import matplotlib.pyplot as plt

x = data2['Metadata.Genres'].head(26)
y = data2['Metrics.Used Price'].head(26)

fig, ax = plt.subplots(figsize=(8, 6))


ax.bar(x, y, color='r')


ax.set_xlabel('Metadata.Genres')
ax.set_ylabel('Metrics.Used Price')
ax.set_title('Price')

plt.xticks(rotation='vertical')


plt.show()

# %% [markdown]
# Histogram

# %%
import pandas as pd
import matplotlib.pyplot as plt

x = data2['Metrics.Used Price'].head(50)


fig, ax = plt.subplots(figsize=(8, 6))


ax.hist(x, bins=25, color='y')


ax.set_xlabel('Metrics.Used Price')
ax.set_ylabel('Frequency')
ax.set_title('Price of Video Games')


plt.show()

# %% [markdown]
# Pie Chart

# %%
Publishers = ['Nintendo', 'EA,Namco', 'Sony', 'Konami', 'Activision', 'Sega', 'Ubisoft']
Sales = [4.69, 0.06, 0.49, 0.06, 0.45, 0.06, 0.49]

# %%
plt.pie(Sales, labels= Publishers)
plt.show()

# %% [markdown]
# Pie Chart with Numerical

# %%
plt.pie(Sales,labels= Publishers, autopct='%2.2f%%')

plt.show()

# %% [markdown]
# Linear Regression

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(array_x,array_y, random_state= 42, test_size=0.3)

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Original Score')
vv = [0,20,40,60,80,100]
plt.plot(vv,vv, color ='red')
plt.ylabel('predicted Score')
plt.show()

# %%
import sklearn
from sklearn import metrics
sklearn.metrics.r2_score(y_test,y_pred)
# Out:
# 0.01674082547777256

# %% [markdown]
# Classification

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=40, metric='minkowski',p=2)
x= array_x
y= array_y
knn.fit(x,y)
# Out:
# KNeighborsClassifier(n_neighbors=40)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(array_x, array_y, test_size=0.3,random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=40)
knn.fit(x_train , y_train)
y_predict = knn.predict(x_test)
y_predict
# Out:
# array([75, 65, 65, 68, 68, 74, 65, 65, 68, 68, 68, 67, 68, 68, 67, 68, 65,
#        67, 73, 68, 68, 68, 68, 67, 65, 68, 67, 67, 68, 74, 68, 67, 75, 67,
#        75, 67, 65, 68, 67, 74, 65, 68, 75, 65, 65])

# %%
knn.score(x_test, y_test)
# Out:
# 0.022222222222222223

# %%
neighbors = np.arange(1,60)

train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))

for i,k in enumerate(neighbors):
  knn_model = KNeighborsClassifier(n_neighbors=k)
  knn_model.fit(x_train , y_train)
  train_accuracy[i] = knn_model.score(x_train, y_train)
  test_accuracy[i] = knn_model.score(x_test, y_test)

plt.plot(neighbors,test_accuracy, label = 'Testing Accuracy')
plt.plot(neighbors, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.xlabel('number of Neighbors')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# Clustering

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
features = data2[['Metrics.Used Price', 'Metrics.Sales']]

# %%
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(features_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
cluster_labels = kmeans.labels_

# %%
centroids = kmeans.cluster_centers_

# %%
data2['cluster'] = cluster_labels

# %%
plt.scatter(features_scaled[:, 0], features_scaled[:, 1], c=cluster_labels)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=100, marker='*', linewidth=10, label='Centroids')
plt.xlabel("Feature 1 (scaled)")
plt.ylabel("Feature 2 (scaled)")
plt.title("K-Means Clustering with Centroids")
plt.legend()
plt.show()

# %%
centroids
# Out:
# array([[-1.23009631, -0.22878237],
#        [ 0.34769238, -0.11448978],
#        [ 1.99069655,  5.20746092]])

# %%
kmeans.inertia_
# Out:
# 101.28344157579082

# %%
inertia_list = []
for k in np.arange(1,10):
  kmeans = KMeans(n_clusters = k)
  kmeans.fit(features)
  inertia_list.append(kmeans.inertia_)
inertia_list
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(np.arange(1,10),inertia_list,'o-',c='red')
plt.xlabel('number of clusters')
plt.ylabel('Inertia')
plt.show()
